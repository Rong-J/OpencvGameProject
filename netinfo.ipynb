# %%
# 导入urllib3库
import urllib3
# 创建PoolManager实例
http = urllib3.PoolManager()
# 通过reques方法创建请求，此处使用GET方法
rq = http.request('GET', 'https://www.swufe.edu.cn/')
# 查看服务器响应码
print("服务器响应码:", rq.status)
# 查看响应实体
print("响应实体:", rq.data)
# Out:
# 服务器响应码: 200
# 响应实体: b'\xef\xbb\xbf<!DOCTYPE html>\r\n<HTML>\r\n<HEAD>\r\n<TITLE>\xe8\xa5\xbf\xe5\x8d\x97\xe8\xb4\xa2\xe7\xbb\x8f\xe5\xa4\xa7\xe5\xad\xa6</TITLE><META Name="keywords" Content="\xe8\xa5\xbf\xe5\x8d\x97\xe8\xb4\xa2\xe7\xbb\x8f\xe5\xa4\xa7\xe5\xad\xa6" />\r\n\r\n<META content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">\r\n<META content="text/html; charset=UTF-8" http-equiv="Content-Type">\r\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\r\n<meta http-equiv="pragma" content="no-cache">\r\n<meta http-equiv="cache-control" content="no-cache">\r\n<meta http-equiv="expires" content="0">\r\n<meta http-equiv="X-UA-Compatible" content="IE=EmulateIE9" />\r\n<LINK rel="stylesheet" type="text/css" href="images/style.css">\r\n<LINK rel="stylesheet" type="text/css" href="css/style.css">\r\n<LINK rel="stylesheet" type="text/css" href="css/swiper-bundle.min.css">\r\n<LINK rel="stylesheet" type="text/css" href="css/styleswbun.css">\r\n<script src="js/jquery.js" type="text/javascript"></script>\r\n<script src="js/SuperSlide.js" type="text/javascript">\r\n</script><script src="js/html5.js" type="text/javascript"></script>\r\n<script type="text/javascript" src="js/new.js"></script>\r\n<!--Announced by Visual SiteBuilder 9-->\r\n<link rel="stylesheet" type="text/css" href="_sitegray/_sitegray_d.css" />\r\n<script language="javascript" src="_sitegray/_sitegray.js"></script>\r\n<!-- CustomerNO:7765626265723230747647545352574603090105 -->\r\n<link rel="stylesheet" type="text/css" href="index.vsb.css" />\r\n<script type="text/javascript" src="/system/resource/js/vsbscreen.min.js" id="_vsbscreen" devices="pc|pad"></script>\r\n<script type="text/javascript" src="/system/resource/js/counter.js"></script>\r\n<script type="text/javascript">_jsq_(1001,\'/index.jsp\',-1,1396514425)</script>\r\n</HEAD>\r\n<BODY>\r\n<DIV class="wrapper"><!--\xe5\xa4\xb4\xe9\x83\xa8\xe5\xbc\x80\xe5\xa7\x8b-->\r\n<DIV class="header">\r\n<DIV class="w962">\r\n<DIV class="topline">\r\n</DIV>\r\n<DIV class="i-top"><!--#begineditable contype="" name="LOGO" action="" layout="" clone="0" namechanged="0" order="1" ispublic="0" tagname="LOGO" viewid="193788" contentviewid="" stylesysid=""-->\r\n <div class="logo"><a href=""><img src="images/logo/newnewlogo.jpg" alt="" /></a></div><!--#endeditable-->\r\n<!--#begineditable contype="" name="logo\xe5\x8f\xb3\xe4\xbe\xa7\xe9\x93\xbe\xe6\x8e\xa5" action="" layout="" clone="0" namechanged="0" order="2" ispublic="0" tagname="logo\xe5\x8f\xb3\xe4\xbe\xa7\xe9\x93\xbe\xe6\x8e\xa5" viewid="193789" contentviewid="" stylesysid=""--><script language="javascript" src="/system/resource/js/openlink.js"></script><div class="toplink">\r\n                 <ul>\r\n                    <li><a href="http://e.swufe.edu.cn"><b>English</b></a></li>                   \r\n                    <LI> <A href="http://smail.swufe.edu.cn" target="_blank">\xe5\xad\xa6\xe7\x94\x9f\xe9\x82\xae\xe7\xae\xb1</a></li>\r\n                    <LI> <A href="http://mail.swufe.edu.cn" target="_blank">\xe6\x95\x99\xe5\xb7\xa5\xe9\x82\xae\xe7\xae\xb1</a></li>\r\n                    <!--\r\n<LI> <A href="http://zb.swufe.edu.cn" target=_blank>\xe6\x9c\xaa\xe6\x9d\xa5\xe5\xad\xa6\xe7\x94\x9f</a></li>\r\n<LI> <A href="http://e.swufe.edu.cn" target=_blank>\xe5\x9b\xbd\xe9\x99\x85\xe5\xad\xa6\xe7\x94\x9f</a></li>\r\n<LI> <A href="http://xyzh.swufe.edu.cn" target=_blank>\xe6\xaf\x95\xe4\xb8\x9a\xe6\xa0\xa1\xe5\x8f\x8b</a></li>\r\n<LI> <A href="http://oa.swufe.edu.cn" target=_blank>\xe6\x95\x99\xe8\x81\x8c\xe5\x91\x98\xe5\xb7\xa5</a></li>\r\n<LI> <A href="http://xgb.swufe.edu.cn" target=_blank>\xe5\x9c\xa8\xe6\xa0\xa1\xe5\xad\xa6\xe7\x94\x9f</a></li>-->\r\n </ul>   \r\n                </div><!--#endeditable-->\r\n</DIV>\r\n</DIV><!--nav--></DIV>\r\n <div class="navBar">\r\n        <!--#begineditable name="\xe7\xbd\x91\xe7\xab\x99\xe5\xaf\xbc\xe8\x88\xaa" viewid="193786" tagname="\xe7\xbd\x91\xe7\xab\x99\xe5\xaf\xbc\xe8\x88\xaa" action="" layout="" contype="" stylesys ...

# %%
url = 'https://www.swufe.edu.cn/'
rq = http.request('GET',url, retries = 10)
# 分别设置5次请求重试次数与4次重定向的retries参数
rq = http.request('GET',url, retries =5,redirect = 4)
# 同时关闭请求重试与重定向
rq = http.request('GET',url, retries = False)
# 仅关闭重定向
rq = http.request('GET',url, redirect = False)
# 在PoolManager实例中设置retries参数
http = urllib3.PoolManager(retries = 5)
http = urllib3.PoolManager(timeout = urllib3.Retry(5,read = 4))

# %%
import urllib3
http = urllib3.PoolManager()
url = 'https://www.swufe.edu.cn/'
ua = {'User-Agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) Chrome/65.0.3325.181'}
rq = http.request('GET',url,headers = ua)
http = urllib3.PoolManager(timeout = 4.0)
http = urllib3.PoolManager(timeout = urllib3.Timeout(connect = 1.0 , read = 3.0))
http = urllib3.PoolManager(retries = 5)
http = urllib3.PoolManager(timeout = urllib3.Retry(5,read = 4))
print(rq)
# Out:
# <urllib3.response.HTTPResponse object at 0x0000019A8288D3D0>

# %%
# 创建PoolManager实例
http = urllib3.PoolManager()
# 目标url
url = 'https://www.swufe.edu.cn/'
# 设置请求头，UA信息
ua = {'User-Agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) Chrome/65.0.3325.181'}
# 设置超时时间
tm = urllib3.Timeout(connect = 1.0 , read = 3.0)
# 设置重试次数并生成请求
rq = http.request('GET',url, headers = ua,timeout = tm, retries = 5 , redirect = 4)
print(rq)
# 查看服务器响应码
print("服务器响应码:", rq.status)
# 查看获取的内容
print("获取的内容:", rq.data.decode('utf-8'))
# Out:
# <urllib3.response.HTTPResponse object at 0x0000019A8288D490>
# 服务器响应码: 200
# 获取的内容: ﻿<!DOCTYPE html>
# <HTML>
# <HEAD>
# <TITLE>西南财经大学</TITLE><META Name="keywords" Content="西南财经大学" />
#
# <META content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
# <META content="text/html; charset=UTF-8" http-equiv="Content-Type">
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="pragma" content="no-cache">
# <meta http-equiv="cache-control" content="no-cache">
# <meta http-equiv="expires" content="0">
# <meta http-equiv="X-UA-Compatible" content="IE=EmulateIE9" />
# <LINK rel="stylesheet" type="text/css" href="images/style.css">
# <LINK rel="stylesheet" type="text/css" href="css/style.css">
# <LINK rel="stylesheet" type="text/css" href="css/swiper-bundle.min.css">
# <LINK rel="stylesheet" type="text/css" href="css/styleswbun.css">
# <script src="js/jquery.js" type="text/javascript"></script>
# <script src="js/SuperSlide.js" type="text/javascript">
# </script><script src="js/html5.js" type="text/javascript"></script>
# <script type="text/javascript" src="js/new.js"></script>
# <!--Announced by Visual SiteBuilder 9-->
# <link rel="stylesheet" type="text/css" href="_sitegray/_sitegray_d.css" />
# <script language="javascript" src="_sitegray/_sitegray.js"></script>
# <!-- CustomerNO:7765626265723230747647545352574603090105 -->
# <link rel="stylesheet" type="text/css" href="index.vsb.css" />
# <script type="text/javascript" src="/system/resource/js/vsbscreen.min.js" id="_vsbscreen" devices="pc|pad"></script>
# <script type="text/javascript" src="/system/resource/js/counter.js"></script>
# <script type="text/javascript">_jsq_(1001,'/index.jsp',-1,1396514425)</script>
# </HEAD>
# <BODY>
# <DIV class="wrapper"><!--头部开始-->
# <DIV class="header">
# <DIV class="w962">
# <DIV class="topline">
# </DIV>
# <DIV class="i-top"><!--#begineditable contype="" name="LOGO" action="" layout="" clone="0" namechanged="0" order="1" ispublic="0" tagname="LOGO" viewid="193788" contentviewid="" stylesysid=""-->
#  <div class="logo"><a href=""><img src="images/logo/newnewlogo.jpg" alt="" /></a></div><!--#endeditable-->
# <!--#begineditable contype="" name="logo右侧链接" action="" layout="" clone="0" namechanged="0" order="2" ispublic="0" tagname="logo右侧链接" viewid="193789" contentviewid="" stylesysid=""--><script language="javascript" src="/system/resource/js/openlink.js"></script><div class="toplink">
#                  <ul>
#                     <li><a href="http://e.swufe.edu.cn"><b>English</b></a></li>
#                     <LI> <A href="http://smail.swufe.edu.cn" target="_blank">学生邮箱</a></li>
#                     <LI> <A href="http://mail.swufe.edu.cn" target="_blank">教工邮箱</a></li>
#                     <!--
# <LI> <A href="http://zb.swufe.edu.cn" target=_blank>未来学生</a></li>
# <LI> <A href="http://e.swufe.edu.cn" target=_blank>国际学生</a></li>
# <LI> <A href="http://xyzh.swufe.edu.cn" target=_blank>毕业校友</a></li>
# <LI> <A href="http://oa.swufe.edu.cn" target=_blank>教职员工</a></li>
# <LI> <A href="http://xgb.swufe.edu.cn" target=_blank>在校学生</a></li>-->
#  </ul>
#                 </div><!--#endeditable-->
# </DIV>
# </DIV><!--nav--></DIV>
#  <div class="navBar">
#         <!--#begineditable name="网站导航" viewid="193786" tagname="网站导航" action="" layout="" contype="" stylesysid="" template="" tplstyle="" clone="" istemp=""--><ul class="nav clearfix">
#   <li id="m1" class="m">
#                 <h3> <a href="index.htm" title="首页">首页</a> </h3>
#             </li>
#
# <li class="s">|</li>
#   <li id="m2" class="m">
#                 <h3> <a href="xxgk/xxjj.htm" title="学校概况">学校概况</a> </h3>
#                 <ul class="sub">
#  <li><a href="xxgk/xxjj.htm" title="学校简介">学校简介</a> </li>
# <li class="s">|</li>
#  <li><a href="xxgk/xxld.htm" title="学校领导">学校领导</a> </li>
# <li class="s">|</li>
#  <li><a href="xxgk/lsyg.htm" title="历史沿革">历史沿革</a> </li>
# <li class="s">|</li>
#  <li><a href="xxgk/xyfg.htm" title="校园风光">校园风光</a> </li>
# <li class="s">|</li>
#  <li><a href="https://gis.swufe.edu.cn" title="校园导航">校园导航</a> </li>
#
#
#                 </ul>
#             </li>
#
# <li class="s">|</li>
#   <li id="m3" class="m">
#                 <h3> <a href="rcpy1.htm" title="人才培养">人才培养</a> </h3>
#                 <ul class="sub">
#  <li><a href="http://jwc.swufe.edu.cn/" title="本科生教育">本科生教育</a> </li>
# <li class="s">|</li>
#  <li><a href="http://graduate.swufe.edu.cn/" title="研究生教育">研究生教育</a> </li>
# <li class="s">|</li>
#  <li><a href="rcpy1/zyxwjy.htm" title="专业学位教育">专业学位教育</a> </li>
# <li class="s">|</li>
#  <li><a href="http://xczx.swufe.edu.cn/v2012/index.html" title="继续教育">继续教育</a> </li>
# <li class="s">|</li>
#  <li><a href="http://international.swufe.edu.cn/" title="留学生">留学生</a> </li>
# <li class="s">|</li>
#  <li><a href="http://liuxue.swufe.edu.cn/" title="出国预备教育">出国预备教育</a> </li>
# <li class="s">|</li>
#  <li><a href="http://ganxun.swufe.edu.cn" title="干部培训">干部培训</a> </li>
#
#
#                 </ul>
#             </li>
#
# <li class="s">|</li>
#   <li id="m4" class="m">
#                 <h3> <a href="szdw/szgk.htm" title="师资队伍">师资队伍</a> </h3>
#                 <ul class="sub">
#  <li><a href="szdw/szgk.htm" title="师资概况">师资概况</a> </li>
#
#
#                 </ul>
#             </li>
#
# <li class="s">|</li>
#   <li id="m5" class="m">
#                 <h3> <a href="kxyj1.htm" title="科学研究">科学研究</a> </h3>
#             </li>
#
# <li class="s">|</li>
#   <li id="m6" class="m">
#                 <h3> <a href="zsjy.htm" title="招生就业">招生就业</a> </h3>
#                 <ul class="sub">
#  <li><a href="http://zb.swufe.edu.cn" title="本科生招生">本科生招生</a> </li>
# <li class="s">|</li>
#  <li><a href="http://yz.swufe.edu.cn" title="研究生招生">研究生招生</a> </li>
#  <li><a href="http://dag.swufe.edu.cn" title="档案服务">档案服务</a> </li>
# <li class="s">|</li>
#  <li><a href="http://xwgk.swufe.edu.cn" title="信息公开">信息公开</a> </li>
#
#
#                 </ul>
#             </li>
#
#
# </ul>
#
# <!--#endeditable-->
#     </div>
#      <script type="text/javascript">jQuery(".nav").slide({ type:"menu",  titCell:".m", targetCell:".sub", delayTime:300, triggerTime:0,returnDefault:true  });   </script>
#    <!--#begineditable name="logoes" action="webber.wbst.com.news.ColumnNews" layout="/system/_component/news/list/tpltitlelist.jsp" tpltype="1" contype="news" clone="" viewid="247812" contentviewid="" tagname="logoes"--> <div class="swiper-container" style="width:100%;height:100%;">
#     <div class="swiper-wrapper">
#              <div class="swiper-slide">
#      <a href=""><img src="/__local/D/B6/E5/65D4E46B3135DC6209ACB3C998A_09EC3EDF_ADB26.jpg" style="width:100%;height:100%;" /> </a>
#             </div>
#       <div class="swiper-slide">
#      <a href=""><img src="/__local/8/00/C2/C34222AA2186695731CC5B46242_88C46E54_9F2C5.jpg" style="width:100%;height:100%;" /> </a>
#             </div>
#       <div class="swiper-slide">
#      <a href=""><img src="/__local/2/AF/AF/7D49BB2842BCBD1B7DD0F227723_FF2AD034_A703D.jpg" style="width:100%;height:100%;" /> </a>
#             </div>
#       <div class="swiper-slide">
#      <a href=""><img src="/__local/E/39/0D/0CE36C8FB06F24DEFF0318270AE_30DFCFE6_A7130.jpg" style="width:100%;height:100%;" /> </a>
#             </div>
#       <div class="swiper-slide">
#      <a href="http://dsxxjy.swufe.edu.cn"><img src="/__local/5/15/D1/F16E203F60CA6C2319C4799E200_6448E5C8_A2BA1.jpg" style="width:100%;height:100%;" /> </a>
#             </div>
#       <div class="swiper-slide">
#      <a href="https://dsxxjy.swufe.edu.cn"><img src="/__local/9/F5/70/1483D5076C594046F3F12CB0C25_2C0E9D5C_A1E1E.jpg" style="width:100%;height:100%;" /> </a>
#             </div>
#       <div class="swiper-slide">
#      <a href="#"><img src="/__local/C/99/6B/451CAB5563F59A188A4E095FB63_825C95C3_1F2676.jpg" style="width:100%;height:100%;" /> </a>
#             </div>
#       <div class="swiper-slide">
#      <a href="#"><img src="/__local/3/C9/2D/4FAF4E764DAC8AE4501B9497E29_A531998A_4613A5.jpg" style="width:100%;height:100%;" /> </a>
#             </div>
#       <div class="swiper-slide">
#      <a href="#"><img src="/__local/4/5D/0E/EF8F0D5BB7E21F1DC34DCC6A57C_308DE32F_33D1EE.jpg" style="width:100%;height:100%;" /> </a>
#             </div>
#
#
#     </div>
#     <div class="swiper-button-next"></div>
#     <div class="swiper-button-prev"></div>
#     <DIV class="swiper-pagination"></DIV>
#   </div>
#
#
#
# <!--#endeditable-->
#
# <DIV class="navBar2">
#
#
#
#
#
#
#     <!--主要新闻区开始-->
#     <div class="mianpad1"></div>
# <DIV class="i-main clearfix">
# <!--p--><!--#begineditable contype="" name="西财新闻" action="" layout="" clone="0" namechanged="0" order="6" ispublic="0" tagname="西财新闻" viewid="193792" contentviewid="" stylesysid=""--><div class="i-news">
#             <div class="i_title"><h1>西财新闻</h1><span>
#              <a href="http://dsxxjy.swufe.edu.cn"><font color="red">党史学习教育专题网站>></font></a>&nbsp;&nbsp;&nbsp;&nbsp;
#            <a href="http://news.swufe.edu.cn/fyfyzt.htm"><font color="red">全力做好新冠疫情防控工作>></font></a>&nbsp;&nbsp;&nbsp;&nbsp;
#
#            <a href="http://news.swufe.edu.cn" target="_blank"><h7>进入新闻网>></h7></a></span></div>
#
#             <ul class="focusList clearfix" id="xicai_news">
#
#  <li>
# <a href="info/1002/18518.htm" target="_blank" title="中国共产党西南财经大学第十三届代表大会第四次会议举行"><img src="/__local/D/20/FD/BE42B331E84759DD513A3D8B1CE_EE5F47F0_43BA5.jpg" width="200" height="100"></a>
#                     <div class="tn">
#                         <h3><a href="info/1002/
#                     <div class="tn">
#                         <h3><a href="info/1002/18658.htm" target="_blank" title="我校“凉山州大型易地扶贫搬迁社区治理创新实验工作”项目入选教育部直属高校服务乡村振兴创新实验培育项目">我校“凉山州大型易地扶贫搬迁社区治理创新实验工作”项目入选教育部直属高校服务乡村振兴创新实验培育项目</a></h3>
#                         <p>​近日，教育部公布了第二批教育部直属高校服务乡村振新创新试验培育项目,我校社会发展研究院在凉山州美姑县开展的《凉山州大型易地扶贫搬迁社区治理创新实验工作》项目成功入选。该项目旨在深入贯彻落实习近平总书记考察易地扶贫搬迁安置地时重要讲话精神，充分发挥学校社会工作、社会学专业优势，以凉山州大型易地扶贫搬迁社区的基层组织建设为主线，提供“社区治理人才培养”“居民参与社区治理平台搭建”“焦点问题回应”“...</p>
#                     </div>
#                 </li>
#
#
#  </ul>
#
#         </div>
# <!--#endeditable--><!--p-->
#
# <!--i-ztbox-->
#     <div class="i-ztbox">
#         <div class="i-zt">
#                 <ul class="picList">
#
#  <li style="margin-right:50px;margin-left:5px;">
#                         <div class="pic"> <a href="https://www.xuexi.cn/cc72a0454287bdedb7e2c156db55e818/71eb7214c6c0c1f5e6ec6e29564decb4.html" title="" target="_blank">
#                             <img src="images/zt/ZT_01.jpg" width="200" height="100">
#                         </a>  </div>
#                     </li>
#
#
#
#  <li style="margin-right:55px;">
#                         <div class="pic"> <a href="http://www.moe.gov.cn/jyb_xwfb/xw_zt/moe_357/s7865/s8417/" title="" target="_blank">
#                             <img src="images/zt/ZT_02.jpg" width="200" height="100">
#                         </a>  </div>
#                     </li>
#
#
#
#  <li style="margin-right:50px;">
#                         <div class="pic"> <a href="http://bwcx.swufe.edu.cn" title="" target="_blank">
#                             <img src="images//zt/ZT_03.jpg" width="200" height="100">
#                         </a>  </div>
#                     </li>
#
#
#
#  <li>
#                         <div class="pic"> <a href="http://ddh13.swufe.edu.cn/" title="" target="_blank">
#                             <img src="images/zt/ZT_04.jpg" width="200" height="100">
#                         </a>  </div>
#                     </li>
#  </ul>
#         </div>
#     </div>
#     <!--#begineditable contype="" name="快速链接" action="" layout="" clone="0" namechanged="0" order="7" ispublic="0" tagname="快速链接" viewid="193799" contentviewid="" stylesysid=""--><div class="i-plink">
#             <ul>
# <li><a href="https://mail.swufe.edu.cn/" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1396514425, 37175)" style="background:url(images/iplink0101.png) center no-repeat"></a><span>邮箱</span></a></li>
#
# <li class="lios"><a href="https://ehall.swufe.edu.cn" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1396514425, 37176)" style="background:url(images/iplink02.png) center no-repeat"></a><span>师生事务大厅</span></li>
#
# <li><a href="https://oa.swufe.edu.cn/" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1396514425, 37177)" style="background:url(images/iplink03.png) center no-repeat"></a><span>OA系统</a></span></li>
#
# <li class="lios"><a href="http://www.icourses.cn/school/swufe" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1396514425, 37178)" style="background:url(images/iplink04.png) center no-repeat"></a><span>西财公开课</span></a></li>
#
# <li><a href="https://145gh.swufe.edu.cn" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1396514425, 37179)" style="background:url(images/iplink05.png) center no-repeat"></a><span>十四五规划</span></a></li>
#
# <li class="lios"><a href="http://lib.swufe.edu.cn/" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1396514425, 37180)" style="background:url(images/iplink01.png) center no-repeat"></a><span>图书馆</span></a></li>
#
# <li><a href="http://www.yiban.cn/school/index/id/22009" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1396514425, 37181)" style="background:url(images/iplink07.png) center no-repeat"></a><span>西财易班</span></a></li>
#  </ul>
#         </div><!--#endeditable--><!--p-->
#
# </DIV><!--通知公告区-->
# <DIV class="i-tzgg">
# <DIV class="w1008"><!--#begineditable contype="" name="学术讲座" action="" layout="" clone="0" namechanged="0" order="8" ispublic="0" tagname="学术讲座" viewid="193798" contentviewid="" stylesysid=""--><div class="i-tzgg-l">
#                 <div class="i_title2"><h1>学术讲座</h1><span><a href="index/xsjz.htm">更多&gt;&gt;</a></span></div>
#                 <div class="xsjzlist">
#                     <ul>
#
#   <div class="list">
#                             <div class="pic">
#                                 <div class="month">03-30</div>
#                                 <div class="day">2022</div></div>
#
# <div class="text"><a href="info/1004/18690.htm" target="_blank" title="国家自科和社科基金项目申报经验交流">国家自科和社科基金项目申报...</a><br>
#
#                                  <font1>主讲人：倪红福，中国社会科学院经济研究所研究员、中国社会科学院大学教授</font1>
#                                 <font1>时  间：4月1日下午14:00-15:30</font1>
#                                 <font1>地  点：腾讯会议，会议ID：529-651-652</font1>
#                             </div>
#                             <div class="clear"></div></div>
#
#   <div class="list">
#                             <div class="pic">
#                                 <div class="month">03-30</div>
#                                 <div class="day">2022</div></div>
#
# <div class="text"><a href="info/1004/18689.htm" target="_blank" title="Efficient Numerical Methods for Elliptic Equations with integral fractional Laplacian  (分数阶Laplacian椭圆方程的数值方法)">Efficient Numerical Methods...</a><br>
#
#                                  <font1>主讲人：美国普渡大学 郝朝鹏助理教授</font1>
#                                 <font1>时  间：3月30日9:00</font1>
#                                 <font1>地  点：腾讯会议，会议ID：867-156-138</font1>
#                             </div>
#                             <div class="clear"></div></div>
#
#   <div class="list">
#                             <div class="pic">
#                                 <div class="month">03-29</div>
#                                 <div class="day">2022</div></div>
#
# <div class="text"><a href="info/1004/18688.htm" target="_blank" title="时间分数阶抛物型方程的一些新型数值格式">时间分数阶抛物型方程的一些...</a><br>
#
#                                  <font1>主讲人：华中科技大学数学与统计学院 李东方教授</font1>
#                                 <font1>时  间：3月31日10:00</font1>
#                                 <font1>地  点：腾讯会议，会议ID：231-601-601</font1>
#                             </div>
#                             <div class="clear"></div></div>
#
#   <div class="list">
#                             <div class="pic">
#                                 <div class="month">03-28</div>
#                                 <div class="day">2022</div></div>
#
# <div class="text"><a href="info/1004/18684.htm" target="_blank" title="【全球胜任力系列讲座九】将时装设计灵感变为现实 Fashion Design Process">【全球胜任力系列讲座九】将...</a><br>
#
#                                  <font1>主讲人：罗德岛设计学院 Catherine Andreozzi教授&著名时装设计师</font1>
#                                 <font1>时  间：3月29日晚上21:30-22:30</font1>
#                                 <font1>地  点：ZOOM Meeting ID: 987 8947 4160</font1>
#                             </div>
htm" title="" target="_blank">
# <i><table width="100%" border="0" align="center" cellpadding="0" cellspacing="0">
#   <tr>
#     <td align="center" valign="middle" height="34">计算机与人工智能学院</td>
#   </tr>
# </table></i>
#
# 计算机与人工智能学院教师在国际顶刊TKDE发表论文</a><span class="date">2022-01-13</span></li>
# <li><a href="info/1006/18512.htm" title="" target="_blank">
# <i><table width="100%" border="0" align="center" cellpadding="0" cellspacing="0">
#   <tr>
#     <td align="center" valign="middle" height="34">财税学院</td>
#   </tr>
# </table></i>
#
# 财税学院教师在学校教学竞赛中获得佳绩</a><span class="date">2021-12-29</span></li>
#  <div class="xxys_more"><a href="index/xysx.htm">更多>></a></div>
#
#
#
#
#
#
# <!--#endeditable--></UL>
# </DIV>
# </DIV><script type="text/javascript">jQuery(".xysxtzgg").slide();</script>
# </DIV>
#
#
# </DIV>
# </DIV><!--底部版权开始-->
# <DIV class="footer">
# <DIV class="w962"><!--#begineditable contype="" name="版权" action="" layout="" clone="0" namechanged="0" order="11" ispublic="0" tagname="版权" viewid="193793" contentviewid="" stylesysid=""--><!-- 版权内容请在本组件"内容配置-版权"处填写 -->
# <div class="end_l"><p>柳林校区：</p><p>四川成都温江柳台大道555号 &nbsp;邮编：611130</p><p><br /></p><p>光华校区：</p><p>四川成都光华村街55号 &nbsp; &nbsp;邮编：610074</p> </div><!--#endeditable-->
# <!--#begineditable contype="" name="版权右侧链接" action="" layout="" clone="0" namechanged="0" order="12" ispublic="0" tagname="版权右侧链接" viewid="193794" contentviewid="" stylesysid=""-->
# <div class="end_r">
#                 <ul class="end_link">
#
#   <li><a href="http://gxlz.scedu.net" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1396514425, 37182)" style="background: url(images/wllz.png) center no-repeat"></a><span>网络理政</span></li>
#
#    <li><a href="http://weibo.com/swufe1925" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1396514425, 37182)" style="background: url(images/end_ico01.png) center no-repeat"></a><span>官方微博</span></li>
#
#   <li><a href="http://www.swufe.edu.cn/4692.html" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1396514425, 37183)" style="background: url(images/end_ico02.png) center no-repeat"></a><span>官方微信</span></li>
#
#
#   <li><a href="mailto:minyiqiao@swufe.edu.cn" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1396514425, 37184)" style="background: url(images/end_ico03.png) center no-repeat"></a><span>书记信箱</span></li>
#
#
#   <li><a href="mailto:xiaozhangxinxiang@swufe.edu.cn" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1396514425, 37185)" style="background: url(images/end_ico04.png) center no-repeat"></a><span>校长信箱</span></li>
#
#
#   <li><a href="&lt;span style='color:red;font-size:9pt'&gt;转换链接错误&lt;/span&gt;" title="" onclick="_addDynClicks(&#34;wburl&#34;, 1396514425, 37186)" style="background: url(images/end_ico05.png) center no-repeat"></a><span>校园导航</span></li>
#
#  </ul>
#             </div>
#  <!--#endeditable-->
# </DIV></DIV>
# <DIV class="coyright">西南财经大学&nbsp;&nbsp;版权所有 webmaster@swufe.edu.cn&nbsp;&nbsp;&nbsp;&nbsp; <A href="https://beian.miit.gov.cn">蜀ICP备 05006386-1号</A> &nbsp;&nbsp;&nbsp;&nbsp; <A href="http://www.beian.gov.cn/portal/registerSystemInfo?recordcode=51010502010087"><IMG src="images/wjtb.png"> 川公网安备51010502010087号</A></DIV>
# </DIV>
#
#
#  <script src="js/swiper-bundle.min.js"></script>
#
#   <!-- Initialize Swiper -->
#   <script>
#     var swiper = new Swiper('.swiper-container', {
#       navigation: {
#         nextEl: '.swiper-button-next',
#         prevEl: '.swiper-button-prev',
#       },
#     });
#   </script>
# </BODY></HTML>

# %%
import requests
url = 'https://www.swufe.edu.cn/ ' # 生成GET请求
rqg = requests.get(url)
print("结果类型:", type(rqg))        # 查看结果类型
print("状态码:", rqg.status_code)    # 查看状态码
print("编码:", rqg.encoding)     # 查看编码
print("响应头:", rqg.headers)      # 查看响应头
# Out:
# 结果类型: <class 'requests.models.Response'>
# 状态码: 404
# 编码: ISO-8859-1
# 响应头: {'Server': 'none', 'Date': 'Thu, 31 Mar 2022 01:01:32 GMT', 'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Language': 'zh-CN', 'Content-Encoding': 'gzip'}

# %%
import requests
import chardet
url = 'https://www.swufe.edu.cn/'
rqg = requests.get(url)
print("编码:", rqg.encoding)     # 查看编码
print("detect方法检测结果:", chardet.detect(rqg.content))
rqg.encoding = chardet.detect(rqg.content)['encoding']  # 将检测到的编码赋值给rqg.encoding
print("改变后的编码:", rqg.encoding)     # 查看改变后的编码
# Out:
# 编码: ISO-8859-1
# detect方法检测结果: {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}
# 改变后的编码: UTF-8-SIG

# %%
import re
a = '''asdfsafhellopass:
    234455
    worldafdsf
    '''
b = re.findall('hello(.*?)world',a)
c = re.findall('hello(.*?)world',a,re.S)
print( 'b is ' , b)
print('c is ' , c)
# Out:
# b is  []
# c is  ['pass:\n    234455\n    ']

# %%
s = 'hello1world\nhello2world\nhello3world'
#re.M 多行模式
result1 = re.findall(r'\d.*d', s, re.M)
print(result1)
#re.S 单行模式(可以看成将所有的字符串放在一行内匹配包括换行符\n)
result2 = re.findall(r'\d.*d', s, re.S)
print(result2)
# Out:
# ['1world', '2world', '3world']
# ['1world\nhello2world\nhello3world']

# %%
import re
# 调用requests库获取的网页
import requests
import chardet
url = 'https://www.swufe.edu.cn/info/1002/18658.htm'
ua = {'User-Agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) Chrome/65.0.3325.181'}
rqg = requests.get(url,headers = ua)
rqg.encoding = chardet.detect(rqg.content)['encoding']
# 使用search方法查找title中的内容
title_pattern = r'(?<=<title>).*?(?=</title>)'  
title_com = re.compile(title_pattern,re.M|re.S)  
title_search = re.search(title_com,rqg.text)
title = title_search.group()
print("标题内容:", title)
# 使用findall方法查找title中的内容
print("标题内容:", re.findall(r'<title>(.*?)</title>',rqg.text))
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# F:\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# F:\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# F:\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# F:\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# F:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# F:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# F:\Anaconda\lib\site-packages\urllib3\connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         conn = self._new_conn()
#     359         hostname = self.host
#
# F:\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x0000019A83B17460>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# F:\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# F:\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# F:\Anaconda\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='www.swufe.edu.cn', port=443): Max retries exceeded with url: /info/1002/18658.htm (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019A83B17460>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13088/291679273.py in <module>
#       5 url = 'https://www.swufe.edu.cn/info/1002/18658.htm'
#       6 ua = {'User-Agent' : 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) Chrome/65.0.3325.181'}
# ----> 7 rqg = requests.get(url,headers = ua)
#       8 rqg.encoding = chardet.detect(rqg.content)['encoding']
#       9 # 使用search方法查找title中的内容
#
# F:\Anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# F:\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# F:\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# F:\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# F:\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.swufe.edu.cn', port=443): Max retries exceeded with url: /info/1002/18658.htm (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000019A83B17460>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。'))
